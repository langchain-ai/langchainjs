// %%
// Auto-generated, ignore.
import "../../../../scripts/create_global_node_vars.js"
// Out:
// [Module: null prototype] {  }

// %% [markdown]
// # OpenAI Assistant
//
// :::info
//
// The [OpenAI Assistant API](https://platform.openai.com/docs/assistants/overview) is still in beta.
//
// :::
//
// OpenAI released a new API for a conversational agent like system called Assistant.
//
// You can interact with OpenAI Assistants using OpenAI tools or custom tools. When using exclusively OpenAI tools, you can just invoke the assistant directly and get final answers. When using custom tools, you can run the assistant and tool execution loop using the built-in `AgentExecutor` or write your own executor.
// OpenAI assistants currently have access to two tools hosted by OpenAI: [code interpreter](https://platform.openai.com/docs/assistants/tools/code-interpreter), and [knowledge retrieval](https://platform.openai.com/docs/assistants/tools/knowledge-retrieval).
//
// We've implemented the assistant API in LangChain with some helpful abstractions. In this guide we'll go over those, and show how to use them to create powerful assistants.

// %% [markdown]
// ## Creating an assistant
//
// Creating an assistant is easy. Use the `createAssistant` method and pass in a model ID, and optionally more parameters to further customize your assistant.

// %%
import { OpenAIAssistantRunnable } from "langchain/experimental/openai_assistant";

const assistant = await OpenAIAssistantRunnable.createAssistant({
  model: "gpt-4-1106-preview",
});
await assistant.invoke({
  content: "Hello world!",
});
// Out:
// [
//   {
//     id: "msg_5WRVMVgciA8v3ldUEPo1STxG",
//     object: "thread.message",
//     created_at: 1704228199,
//     thread_id: "thread_jpuo2hk8ollfIAxsp53AoZU9",
//     role: "assistant",
//     content: [
//       {
//         type: "text",
//         text: {
//           value: "Hello! How can I assist you today? If you have any questions or need information, feel free to ask.",
//           annotations: []
//         }
//       }
//     ],
//     file_ids: [],
//     assistant_id: "asst_kVic7w3NMi80MHkOUl07qMuC",
//     run_id: "run_t0aAJUuALkiZH48krSUbBpbk",
//     metadata: {}
//   }
// ]

// %% [markdown]
// If you run into an apiKey error, you can try to pass it directly as clientOptions:

// %%
const assistant = await OpenAIAssistantRunnable.createAssistant({
  clientOptions: { apiKey: process.env.OPENAI_API_KEY as string },
  model: "gpt-4-1106-preview",
});

// %% [markdown]
// If you have an existing assistant, you can pass it directly into the constructor:

// %%
const assistant = new OpenAIAssistantRunnable({
  assistantId: "asst_RtW03Vs6laTwqSSMCQpVND7i",  // Replace with your assistant ID
  // asAgent: true
});

// %% [markdown]
// In this next example we'll show how you can turn your assistant into an agent.

// %% [markdown]
// ## Assistant as an agent

// %%
import { AgentExecutor } from "langchain/agents";
import { StructuredTool } from "langchain/tools";
import { OpenAIAssistantRunnable } from "langchain/experimental/openai_assistant";
import * as z from "zod";

// %% [markdown]
// The first step is to define a list of tools you want to pass to your assistant.
// Here we'll only define one for simplicity's sake, however the assistant API allows for passing in a list of tools, and from there the model can use multiple tools at once.
// Read more about the run steps lifecycle [here](https://platform.openai.com/docs/assistants/how-it-works/runs-and-run-steps)
//
// :::note
// Only models released >= 1106 are able to use multiple tools at once. See the full list of OpenAI models [here](https://platform.openai.com/docs/models).
// :::

// %%
function getCurrentWeather(location: string, _unit = "fahrenheit") {
  if (location.toLowerCase().includes("tokyo")) {
    return JSON.stringify({ location, temperature: "10", unit: "celsius" });
  } else if (location.toLowerCase().includes("san francisco")) {
    return JSON.stringify({ location, temperature: "72", unit: "fahrenheit" });
  } else {
    return JSON.stringify({ location, temperature: "22", unit: "celsius" });
  }
}
class WeatherTool extends StructuredTool {
  schema = z.object({
    location: z.string().describe("The city and state, e.g. San Francisco, CA"),
    unit: z.enum(["celsius", "fahrenheit"]).optional(),
  });

  name = "get_current_weather";

  description = "Get the current weather in a given location";

  constructor() {
    super(...arguments);
  }

  async _call(input: { location: string; unit: string }) {
    const { location, unit } = input;
    const result = getCurrentWeather(location, unit);
    return result;
  }
}
const tools = [new WeatherTool()];

// %% [markdown]
// In the above code we've defined three things:
//
// - A function for the agent to call if the model requests it.
// - A tool class which we'll pass to the `AgentExecutor`
// - The tool list we can use to pass to our `OpenAIAssistantRunnable` and `AgentExecutor`
//
// Next, we construct the `OpenAIAssistantRunnable` and pass it to the `AgentExecutor`.

// %%
const agent = await OpenAIAssistantRunnable.createAssistant({
  model: "gpt-3.5-turbo-1106",
  instructions:
    "You are a weather bot. Use the provided functions to answer questions.",
  name: "Weather Assistant",
  tools,
  asAgent: true,
});
const agentExecutor = AgentExecutor.fromAgentAndTools({
  agent,
  tools,
});

// %% [markdown]
// Note how we're setting `asAgent` to `true`, this input parameter tells the `OpenAIAssistantRunnable` to return different, agent-acceptable outputs for actions or finished conversations.
//
// Above we're also doing something a little different from the first example by passing in input parameters for `instructions` and `name`.
// These are optional parameters, with the instructions being passed as extra context to the model, and the name being used to identify the assistant in the OpenAI dashboard.
//
// Finally to invoke our executor we call the `.invoke` method in the exact same way as we did in the first example.

// %%
await agentExecutor.invoke({
  content: "What's the weather in Tokyo and San Francisco?",
});
// Out:
// {
//   output: "The current weather in Tokyo is 10°C, and the current weather in San Francisco is 72°F."
// }

// %% [markdown]
// Here we asked a question which contains two sub questions inside: `What's the weather in Tokyo?` and `What's the weather in San Francisco?`.
// In order for the `OpenAIAssistantRunnable` to answer that it returned two sets of function call arguments for each question, demonstrating it's ability to call multiple functions at once.

// %% [markdown]
// ## Assistant tools
//
// OpenAI currently offers two tools for the assistant API: a [code interpreter](https://platform.openai.com/docs/assistants/tools/code-interpreter) and a [knowledge retrieval](https://platform.openai.com/docs/assistants/tools/knowledge-retrieval) tool.
// You can offer these tools to the assistant simply by passing them in as part of the `tools` parameter when creating the assistant.

// %%
const assistant = await OpenAIAssistantRunnable.createAssistant({
  model: "gpt-3.5-turbo-1106",
  instructions:
    "You are a helpful assistant that provides answers to math problems.",
  name: "Math Assistant",
  tools: [{ type: "code_interpreter" }],
});

// %% [markdown]
// Since we're passing `code_interpreter` as a tool, the assistant will now be able to execute Python code, allowing for more complex tasks normal LLMs are not capable of doing well, like math.

// %%
await assistant.invoke({
  content: "What's 10 - 4 raised to the 2.7",
});
// Out:
// [
//   {
//     id: "msg_gH9tQ6s0CjhbGJqDEjO9FoKN",
//     object: "thread.message",
//     created_at: 1703625783,
//     thread_id: "thread_iDDoAwms3CrL0AZTby0OQs9p",
//     role: "assistant",
//     content: [
//       {
//         type: "text",
//         text: {
//           value: "To solve the expression 10 - 4 raised to the 2.7, you need to follow the order of operations, known "... 544 more characters,
//           annotations: []
//         }
//       }
//     ],
//     file_ids: [],
//     assistant_id: "asst_4SkCTCdLYSelPufZNYQjokes",
//     run_id: "run_hlpDCmAYl8IhoDjIBP38jv52",
//     metadata: {}
//   }
// ]

// %% [markdown]
// Here the assistant was able to utilize the `code_interpreter` tool to calculate the answer to our question.

// %% [markdown]
// ## Retrieves an assistant
//
// Retrieves an assistant.

// %%
import { OpenAIAssistantRunnable } from "langchain/experimental/openai_assistant";

const assistant = new OpenAIAssistantRunnable({
  assistantId: "asst_MazQJOnFHWmpNR0MrQUb4Q3c", // Replace with your assistant ID
});
await assistant.getAssistant();
// Out:
// {
//   id: "asst_MazQJOnFHWmpNR0MrQUb4Q3c",
//   object: "assistant",
//   created_at: 1703625650,
//   name: "Math Assistant",
//   description: null,
//   model: "gpt-3.5-turbo-1106",
//   instructions: "You are a helpful assistant that provides answers to math problems.",
//   tools: [ { type: "code_interpreter" } ],
//   file_ids: [],
//   metadata: {}
// }

// %% [markdown]
// ## Modifies an assistant
//
// Modifies an assistant.

// %%
import { OpenAIAssistantRunnable } from "langchain/experimental/openai_assistant";

const assistant = await OpenAIAssistantRunnable.createAssistant({
  name: "Personal Assistant",
  model: "gpt-4-1106-preview",
});
await assistant.modifyAssistant({
  name: "Personal Assistant 2",
});
// Out:
// {
//   id: "asst_K9vvk7lhro7VXF6oCJ5ruBlo",
//   object: "assistant",
//   created_at: 1703625847,
//   name: "Personal Assistant 2",
//   description: null,
//   model: "gpt-4-1106-preview",
//   instructions: null,
//   tools: [],
//   file_ids: [],
//   metadata: {}
// }

// %% [markdown]
// ## Delete an assistant
//
// Delete an assistant.

// %%
import { OpenAIAssistantRunnable } from "langchain/experimental/openai_assistant";

const assistant = await OpenAIAssistantRunnable.createAssistant({
  name: "Personal Assistant",
  model: "gpt-4-1106-preview",
});
await assistant.deleteAssistant();
// Out:
// {
//   id: "asst_41KWv1gzsTUMxqdZKtmHMi1b",
//   object: "assistant.deleted",
//   deleted: true
// }

// %% [markdown]
// # OpenAI Files
//
// Files are used to upload documents that can be used with features like Assistants and Fine-tuning.
//
// We've implemented the File API in LangChain with create and delete. You can see [the official API reference here](https://platform.openai.com/docs/api-reference/files/object).
//
// The `File` object represents a document that has been uploaded to OpenAI.
//
// ```json
// {
//   "id": "file-abc123",
//   "object": "file",
//   "bytes": 120000,
//   "created_at": 1677610602,
//   "filename": "salesOverview.pdf",
//   "purpose": "assistants",
// }
// ```

// %% [markdown]
// ## Create a File
//
// Upload a file that can be used across various endpoints. The size of all the files uploaded by one organization can be up to **100 GB**.
//
// The size of individual files can be a maximum of **512 MB**. See the Assistants Tools guide above to learn more about the types of files supported. The Fine-tuning API only supports `.jsonl` files.

// %%
import { OpenAIFiles } from "langchain/experimental/openai_files";
import * as path from "path";

const openAIFiles = new OpenAIFiles();
const filePath = path.resolve(process.cwd(), `../../../../../../examples/state_of_the_union.txt`);
const fileContents = await readFile(filePath);
const file = new File([fileContents], "state_of_the_union.txt", { type: "text/plain" });
await openAIFiles.createFile({
  file,
  purpose: "assistants",
});
// Out:
// {
//   object: "file",
//   id: "file-6gf6ZpEUHfsqVX6wovVLN7ES",
//   purpose: "assistants",
//   filename: "state_of_the_union.txt",
//   bytes: 39027,
//   created_at: 1703628349,
//   status: "processed",
//   status_details: null
// }

// %% [markdown]
// If you run into an apiKey error, you can try to pass it directly as clientOptions:

// %%
const openAIFiles = new OpenAIFiles({clientOptions: { apiKey: process.env.OPENAI_API_KEY }});

// %% [markdown]
// ## Use File in AI Assistant

// %%
import { OpenAIAssistantRunnable } from "langchain/experimental/openai_assistant";
import { OpenAIFiles } from "langchain/experimental/openai_files";
import * as path from "path";

const openAIFiles = new OpenAIFiles();
const filePath = path.resolve(process.cwd(), `../../../../../../examples/state_of_the_union.txt`);
const fileContents = await readFile(filePath);
const newFile = new File([fileContents], "state_of_the_union.txt", { type: "text/plain" });
const assistantFile = await openAIFiles.createFile({
  file: newFile,
  purpose: "assistants",
});

const agent = await OpenAIAssistantRunnable.createAssistant({
  model: "gpt-3.5-turbo-1106",
  instructions:
    "You are a weather bot. Use the provided functions to answer questions.",
  name: "Weather Assistant",
  tools: [...tools, { type: "retrieval" }],
  asAgent: true,
  fileIds: [assistantFile.id, fineTuneFile.id],
});

// %% [markdown]
// ## Delete a File
//
// Delete a file.

// %%
import { OpenAIFiles } from "langchain/experimental/openai_files";

const openAIFiles = new OpenAIFiles();
await openAIFiles.deleteFile({ fileId: file.id });
// Out:
// { object: "file", id: "file-FuznXaLOGnYrXkSidit8n1Gu", deleted: true }

// %% [markdown]
// ## List all Files
//
// Returns a list of files that belong to the user's organization.
//
// `purpose`?: string
// Only return files with the given purpose.

// %%
import { OpenAIFiles } from "langchain/experimental/openai_files";

const openAIFiles = new OpenAIFiles();
await openAIFiles.listFiles({ purpose: "assistants" });
// Out:
// FileObjectsPage {
//   options: { method: "get", path: "/files", query: {} },
//   response: Response {
//     body: ReadableStream { locked: true },
//     bodyUsed: true,
//     headers: Headers {
//       "access-control-allow-origin": "*",
//       "alt-svc": 'h3=":443"; ma=86400',
//       "cf-cache-status": "DYNAMIC",
//       "cf-ray": "83bc84d03dec82ed-IAD",
//       "content-type": "application/json",
//       date: "Tue, 26 Dec 2023 21:46:50 GMT",
//       "openai-organization": "langchain",
//       "openai-processing-ms": "118",
//       "openai-version": "2020-10-01",
//       server: "cloudflare",
//       "set-cookie": "_cfuvid=I4.GDMaptjMvWz2HtjXa45Qp2C10t90AXPrYqJN1HxY-1703627210445-0-604800000; path=/; domain=.api.o"... 42 more characters,
//       "strict-transport-security": "max-age=15724800; includeSubDomains",
//       "x-request-id": "e62dc879943a0fdc6242e3c7b3656349"
//     },
//     ok: true,
//     redirected: false,
//     status: 200,
//     statusText: "OK",
//     url: "https://api.openai.com/v1/files"
//   },
//   body: {
//     object: "list",
//     has_more: false,
//     data: [
//       {
//         object: "file",
//         id: "file-PKd6argxcSf3tjli3wrHKqCE",
//         purpose: "assistants",
//         filename: "state_of_the_union.txt",
//         bytes: 39027,
//         created_at: 1703627080,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Z4pGeS409mkwWVlB6pQc3Iuv",
//         purpose: "assistants",
//         filename: "state_of_the_union.txt",
//         bytes: 39027,
//         created_at: 1703627038,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-fzWAUt3r20xtuehUoGsYnNlS",
//         purpose: "assistants",
//         filename: "state_of_the_union.txt",
//         bytes: 39027,
//         created_at: 1703627030,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Dj287ESi2Kzi5lAUF3y2BeIR",
//         purpose: "assistants",
//         filename: "state_of_the_union.txt",
//         bytes: 39027,
//         created_at: 1703626950,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-c2u561RD2tmhMrkn8qvag7b3",
//         purpose: "assistants",
//         filename: "langchain_experimental.openai_assistant.base.OpenAIAssistantRunnable — 🦜🔗 LangChain 0.0.335.pdf",
//         bytes: 735444,
//         created_at: 1699923726,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Eof53h1eM4nXdrPbOziNWLtC",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 5881,
//         created_at: 1699853554,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-yPTUtdAMnueBwhQNTeKxqdtb",
//         purpose: "fine-tune",
//         filename: "dataset_ddf2215c-80ba-4163-ba14-8f3fbe9e8495.jsonl",
//         bytes: 201255,
//         created_at: 1699852058,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-rsRB09Vp7pvwDVVL6odG1WBq",
//         purpose: "fine-tune",
//         filename: "dataset_6f4315b2-5e64-4a52-871a-c0a948d49799.jsonl",
//         bytes: 1344648,
//         created_at: 1699852047,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-MndO7ASne2HCENNnNPg3F6Ez",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 6132,
//         created_at: 1699839831,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-8tGLfQ638D8Sgvzjxve5noZa",
//         purpose: "fine-tune",
//         filename: "dataset_03d90f67-c379-4197-b98e-f686e125c28a.jsonl",
//         bytes: 206118,
//         created_at: 1699838019,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-uHrF5qcjlfjaUN4CZG2MFCXY",
//         purpose: "fine-tune",
//         filename: "dataset_0b104590-9dbb-490c-8485-dd100c214cc6.jsonl",
//         bytes: 1389688,
//         created_at: 1699838011,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-3xqvFx0WifAVxb4rSIgZ6Efy",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 6370,
//         created_at: 1699811170,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-cQC6mhkG1pTocJwVwOnJ8VaF",
//         purpose: "fine-tune",
//         filename: "dataset_ad305e46-a24a-4cdc-9434-d59eb4fb36e6.jsonl",
//         bytes: 1430644,
//         created_at: 1699809653,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-l0pgD7GlO2DsjeEztaiOSrvA",
//         purpose: "fine-tune",
//         filename: "dataset_9e63fe1b-073c-4df4-bd96-2b1c3ca34206.jsonl",
//         bytes: 260021,
//         created_at: 1699809646,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-RmYNqw6hL20Xk4AkQF90AYTW",
//         purpose: "fine-tune",
//         filename: "dataset_ad305e46-a24a-4cdc-9434-d59eb4fb36e6.jsonl",
//         bytes: 1430644,
//         created_at: 1699809602,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-QqOAwAgkTRADw9cZWUpIasbu",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 12134,
//         created_at: 1699726950,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Ellq7nvFzCOATYbJFqeHZ3GM",
//         purpose: "fine-tune",
//         filename: "dataset_4b29b651-9c78-465c-8288-2f4491797165.jsonl",
//         bytes: 303679,
//         created_at: 1699724154,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-vtrsHGGlElyQC5fIijRKbNeQ",
//         purpose: "fine-tune",
//         filename: "dataset_98d1d1a6-333e-4eb3-afed-438999db1fe2.jsonl",
//         bytes: 1586725,
//         created_at: 1699724147,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Ptd5Fv4gl1Ctkrchz7OT7Kkz",
//         purpose: "fine-tune",
//         filename: "dataset_98d1d1a6-333e-4eb3-afed-438999db1fe2.jsonl",
//         bytes: 1586725,
//         created_at: 1699724094,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-SzzxPobMGQXX1OuGjnCtcp5j",
//         purpose: "fine-tune",
//         filename: "dataset_4b29b651-9c78-465c-8288-2f4491797165.jsonl",
//         bytes: 303679,
//         created_at: 1699724079,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-SW9VifgPyQCPjILMam8E1j3F",
//         purpose: "fine-tune",
//         filename: "dataset_98d1d1a6-333e-4eb3-afed-438999db1fe2.jsonl",
//         bytes: 1586725,
//         created_at: 1699724058,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-YK7uV0rl4agMaxwxnA4R9CQY",
//         purpose: "assistants",
//         filename: "bye.txt",
//         bytes: 34,
//         created_at: 1699544524,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-04H9L4HPXv55eKu5Zey2tiV4",
//         purpose: "assistants",
//         filename: "hello.txt",
//         bytes: 40,
//         created_at: 1699544491,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-6PzpEZc3wKXunQs2P4Jzh8vW",
//         purpose: "assistants",
//         filename: "hello.txt",
//         bytes: 6,
//         created_at: 1699544466,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-LH8PHlttWLMB6AxGeeaWZauy",
//         purpose: "assistants",
//         filename: "F7oKXC9aQAA8nFE.jpeg",
//         bytes: 365642,
//         created_at: 1699544424,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Pcm29EURO2D1jCTSrnmloCJh",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 5968,
//         created_at: 1696636177,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-fRVITAYeMzy8opvEVcCfOaza",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 5968,
//         created_at: 1696636109,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-yEJblxrJRCXobFF6SMrHQkJA",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 719683,
//         created_at: 1696635338,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-2fxq3YMJtWu3kcsJ4wzWc5j8",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 719683,
//         created_at: 1696635301,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-DPWKrryqZLvz5gU2WTfCtAPr",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 1563,
//         created_at: 1696632854,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-4Y8HVsErnOXtdhIMdfpgMVg1",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 1558,
//         created_at: 1696632828,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-hJx4EFgeMBTUPPoZpmTb8Qjd",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 5742,
//         created_at: 1696632504,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-RMvK3rIVQNmRfUhm4O7EWrme",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 5742,
//         created_at: 1696632449,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-AskxhbS3cPzSLsU3msN2fpc5",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 1562,
//         created_at: 1696574732,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-cfrt7KMxq7UpI2dGdiEC0ZQX",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 1554,
//         created_at: 1696574729,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-NgZcDEyZBkQuPjUyI9Y6cPUG",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 5742,
//         created_at: 1696574345,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-FCkHWNpvTUpZzwfOZyuSA4s5",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 5742,
//         created_at: 1696574336,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-TtwgUdM7aW7ehfeqaUcshTtg",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 20406,
//         created_at: 1695271267,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-LbiTFrHKVAfDnqNROQfoyAh8",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 2939,
//         created_at: 1695269741,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-HtPWASZzc0LLlvEY7ENy0q13",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 2182182,
//         created_at: 1695269567,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-tvMCiFdyYm2dUMapVpshLz92",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 274378,
//         created_at: 1695269321,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-kGrPBJvxZyY2UREqrVCfS1SQ",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 20175,
//         created_at: 1695259469,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-0cV48SeSvxS014Ack1Y7FyHq",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 2303986,
//         created_at: 1695257970,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-AnvsaIFnMrpFHqARI3wzR7Om",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 20165,
//         created_at: 1695105409,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-UrGGUOin9fManPfygLuDlELi",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 2302935,
//         created_at: 1695103517,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-3Jr6Z1mqgUeC99NLGKdTK9VU",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 2303069,
//         created_at: 1695103150,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-6yxuJzqQRGv1GfIzE5Y0Fiqj",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 2379718,
//         created_at: 1695103054,
//         status: "error",
//         status_details: "Invalid file format. Example 40, message 4, value None for key content is not a string."
//       },
//       {
//         object: "file",
//         id: "file-M9L3n30ftD1WUJlfnvsv3sBn",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 2379718,
//         created_at: 1695102971,
//         status: "error",
//         status_details: "Invalid file format. Example 40, message 4, value None for key content is not a string."
//       },
//       {
//         object: "file",
//         id: "file-N3hzCW3E95Q7hYt8RE5rXZHH",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 3824,
//         created_at: 1694301482,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-KcwmPPa01K09HPBOHBlVM930",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 977062,
//         created_at: 1694300541,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-hIhhS9EBm9jvr3bdQ76nEV5D",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 977062,
//         created_at: 1694299996,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-HJnpdWq389i3E1grobYHHg3S",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 973704,
//         created_at: 1694299581,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-itOK2JBz9aDFnbboFVxSlb6v",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 968886,
//         created_at: 1694299411,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-3m080N3WMfXPYpoN5VcKHXET",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 1631,
//         created_at: 1693719731,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-jmqHqJVNMDt8YaWS7JaqSOT2",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 141994,
//         created_at: 1693719081,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-s8yH11pgszUBqIeCbuSrIeeW",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 28398,
//         created_at: 1693719037,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-KMDtl0c72dzAPCsi32zt7LuD",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 3821,
//         created_at: 1693347734,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Zu8UwDylxzikViJ6fhNrX4vO",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 963387,
//         created_at: 1693346963,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-ZtXgzqi7bPhvClEEGhdKeHQ9",
//         purpose: "fine-tune",
//         filename: "examples.jsonl",
//         bytes: 963387,
//         created_at: 1693346812,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-2LQrTDMdAf7RCl9bllkh5fq5",
//         purpose: "fine-tune",
//         filename: "examples.jsonl",
//         bytes: 963387,
//         created_at: 1693346585,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-pVXGYydVdQoZ3ekgQQZNHbS4",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 14882,
//         created_at: 1693090386,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-55KQkM7FjY1zSDQBBHrO3Yjo",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 14873,
//         created_at: 1693088781,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-hh1VsEhfogJrVoGD2o1tQWIC",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 445244,
//         created_at: 1693087291,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Hym38LhaBJIlCmy7ffjGRqcQ",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 2537,
//         created_at: 1692840908,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-5kiW4OE4yNIDtSsgieVQO3aC",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 2534,
//         created_at: 1692834768,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-BIY5uqyb0k1S43c6lUTg78vT",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 2536,
//         created_at: 1692833641,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-AkC9qKP37zaAJrXHSMHCPtfo",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 2536,
//         created_at: 1692832195,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-oRm8O48ZPtfo4V1ojfQkb0Hx",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 8566,
//         created_at: 1692831523,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Vp2tXt7iEcolcWS9fDIDbrJA",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 8566,
//         created_at: 1692831446,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-1r2nUlEWXsMM3l6c3ySNJhVp",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 2537,
//         created_at: 1692830105,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-oJnvEfHJBOjxnw0fwVI07AlM",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 8566,
//         created_at: 1692829400,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Q51jcoJ9j1V4wk1rgCKfGZuU",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 6262,
//         created_at: 1692829324,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-7ySzIB1oBRIDcfiZZSn4FHCM",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 105383,
//         created_at: 1692811809,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-0mZu3g9fMaE0rxC5tgAjiVke",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 1475,
//         created_at: 1692810960,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-03vGq2Q9l136VxrvLB8iflQw",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 105383,
//         created_at: 1692810257,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-YHUbgwZAMZXCz6LtX8UcL5Hb",
//         purpose: "fine-tune-results",
//         filename: "step_metrics.csv",
//         bytes: 2638,
//         created_at: 1692740830,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-61DQYPcXDazjyFdk8gIVwv6J",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 59430,
//         created_at: 1692740164,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-AOVf1DUY9IJZ6DiTlf8OI0du",
//         purpose: "fine-tune",
//         filename: "file",
//         bytes: 59430,
//         created_at: 1692740116,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-YvuO6n7fHa4Ab4f7WLA0LrMY",
//         purpose: "fine-tune-results",
//         filename: "compiled_results.csv",
//         bytes: 38918,
//         created_at: 1683768553,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-ywdSfaiNwSKZPF6sKvJrZhFQ",
//         purpose: "fine-tune",
//         filename: "finetune.jsonl",
//         bytes: 1219476,
//         created_at: 1683767421,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-uSuzKUnX02Vi6Zx4wkAUQTOX",
//         purpose: "fine-tune-results",
//         filename: "compiled_results.csv",
//         bytes: 199355,
//         created_at: 1664822707,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-YquSBCmUrM9lgZqClLcNVXWA",
//         purpose: "fine-tune",
//         filename: "docs_blurbs_prepared.jsonl",
//         bytes: 2773423,
//         created_at: 1664820476,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-Iz6A07iIWaUWOGfH6Tur4YfR",
//         purpose: "fine-tune-results",
//         filename: "compiled_results.csv",
//         bytes: 693,
//         created_at: 1663314732,
//         status: "processed",
//         status_details: null
//       },
//       {
//         object: "file",
//         id: "file-KHQAVwAogvWFjzI8jJ2ZQDJE",
//         purpose: "fine-tune",
//         filename: "training_prepared.jsonl",
//         bytes: 1889,
//         created_at: 1663309724,
//         status: "processed",
//         status_details: null
//       }
//     ]
//   },
//   data: [
//     {
//       object: "file",
//       id: "file-PKd6argxcSf3tjli3wrHKqCE",
//       purpose: "assistants",
//       filename: "state_of_the_union.txt",
//       bytes: 39027,
//       created_at: 1703627080,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Z4pGeS409mkwWVlB6pQc3Iuv",
//       purpose: "assistants",
//       filename: "state_of_the_union.txt",
//       bytes: 39027,
//       created_at: 1703627038,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-fzWAUt3r20xtuehUoGsYnNlS",
//       purpose: "assistants",
//       filename: "state_of_the_union.txt",
//       bytes: 39027,
//       created_at: 1703627030,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Dj287ESi2Kzi5lAUF3y2BeIR",
//       purpose: "assistants",
//       filename: "state_of_the_union.txt",
//       bytes: 39027,
//       created_at: 1703626950,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-c2u561RD2tmhMrkn8qvag7b3",
//       purpose: "assistants",
//       filename: "langchain_experimental.openai_assistant.base.OpenAIAssistantRunnable — 🦜🔗 LangChain 0.0.335.pdf",
//       bytes: 735444,
//       created_at: 1699923726,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Eof53h1eM4nXdrPbOziNWLtC",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 5881,
//       created_at: 1699853554,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-yPTUtdAMnueBwhQNTeKxqdtb",
//       purpose: "fine-tune",
//       filename: "dataset_ddf2215c-80ba-4163-ba14-8f3fbe9e8495.jsonl",
//       bytes: 201255,
//       created_at: 1699852058,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-rsRB09Vp7pvwDVVL6odG1WBq",
//       purpose: "fine-tune",
//       filename: "dataset_6f4315b2-5e64-4a52-871a-c0a948d49799.jsonl",
//       bytes: 1344648,
//       created_at: 1699852047,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-MndO7ASne2HCENNnNPg3F6Ez",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 6132,
//       created_at: 1699839831,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-8tGLfQ638D8Sgvzjxve5noZa",
//       purpose: "fine-tune",
//       filename: "dataset_03d90f67-c379-4197-b98e-f686e125c28a.jsonl",
//       bytes: 206118,
//       created_at: 1699838019,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-uHrF5qcjlfjaUN4CZG2MFCXY",
//       purpose: "fine-tune",
//       filename: "dataset_0b104590-9dbb-490c-8485-dd100c214cc6.jsonl",
//       bytes: 1389688,
//       created_at: 1699838011,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-3xqvFx0WifAVxb4rSIgZ6Efy",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 6370,
//       created_at: 1699811170,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-cQC6mhkG1pTocJwVwOnJ8VaF",
//       purpose: "fine-tune",
//       filename: "dataset_ad305e46-a24a-4cdc-9434-d59eb4fb36e6.jsonl",
//       bytes: 1430644,
//       created_at: 1699809653,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-l0pgD7GlO2DsjeEztaiOSrvA",
//       purpose: "fine-tune",
//       filename: "dataset_9e63fe1b-073c-4df4-bd96-2b1c3ca34206.jsonl",
//       bytes: 260021,
//       created_at: 1699809646,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-RmYNqw6hL20Xk4AkQF90AYTW",
//       purpose: "fine-tune",
//       filename: "dataset_ad305e46-a24a-4cdc-9434-d59eb4fb36e6.jsonl",
//       bytes: 1430644,
//       created_at: 1699809602,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-QqOAwAgkTRADw9cZWUpIasbu",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 12134,
//       created_at: 1699726950,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Ellq7nvFzCOATYbJFqeHZ3GM",
//       purpose: "fine-tune",
//       filename: "dataset_4b29b651-9c78-465c-8288-2f4491797165.jsonl",
//       bytes: 303679,
//       created_at: 1699724154,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-vtrsHGGlElyQC5fIijRKbNeQ",
//       purpose: "fine-tune",
//       filename: "dataset_98d1d1a6-333e-4eb3-afed-438999db1fe2.jsonl",
//       bytes: 1586725,
//       created_at: 1699724147,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Ptd5Fv4gl1Ctkrchz7OT7Kkz",
//       purpose: "fine-tune",
//       filename: "dataset_98d1d1a6-333e-4eb3-afed-438999db1fe2.jsonl",
//       bytes: 1586725,
//       created_at: 1699724094,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-SzzxPobMGQXX1OuGjnCtcp5j",
//       purpose: "fine-tune",
//       filename: "dataset_4b29b651-9c78-465c-8288-2f4491797165.jsonl",
//       bytes: 303679,
//       created_at: 1699724079,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-SW9VifgPyQCPjILMam8E1j3F",
//       purpose: "fine-tune",
//       filename: "dataset_98d1d1a6-333e-4eb3-afed-438999db1fe2.jsonl",
//       bytes: 1586725,
//       created_at: 1699724058,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-YK7uV0rl4agMaxwxnA4R9CQY",
//       purpose: "assistants",
//       filename: "bye.txt",
//       bytes: 34,
//       created_at: 1699544524,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-04H9L4HPXv55eKu5Zey2tiV4",
//       purpose: "assistants",
//       filename: "hello.txt",
//       bytes: 40,
//       created_at: 1699544491,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-6PzpEZc3wKXunQs2P4Jzh8vW",
//       purpose: "assistants",
//       filename: "hello.txt",
//       bytes: 6,
//       created_at: 1699544466,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-LH8PHlttWLMB6AxGeeaWZauy",
//       purpose: "assistants",
//       filename: "F7oKXC9aQAA8nFE.jpeg",
//       bytes: 365642,
//       created_at: 1699544424,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Pcm29EURO2D1jCTSrnmloCJh",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 5968,
//       created_at: 1696636177,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-fRVITAYeMzy8opvEVcCfOaza",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 5968,
//       created_at: 1696636109,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-yEJblxrJRCXobFF6SMrHQkJA",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 719683,
//       created_at: 1696635338,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-2fxq3YMJtWu3kcsJ4wzWc5j8",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 719683,
//       created_at: 1696635301,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-DPWKrryqZLvz5gU2WTfCtAPr",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 1563,
//       created_at: 1696632854,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-4Y8HVsErnOXtdhIMdfpgMVg1",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 1558,
//       created_at: 1696632828,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-hJx4EFgeMBTUPPoZpmTb8Qjd",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 5742,
//       created_at: 1696632504,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-RMvK3rIVQNmRfUhm4O7EWrme",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 5742,
//       created_at: 1696632449,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-AskxhbS3cPzSLsU3msN2fpc5",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 1562,
//       created_at: 1696574732,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-cfrt7KMxq7UpI2dGdiEC0ZQX",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 1554,
//       created_at: 1696574729,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-NgZcDEyZBkQuPjUyI9Y6cPUG",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 5742,
//       created_at: 1696574345,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-FCkHWNpvTUpZzwfOZyuSA4s5",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 5742,
//       created_at: 1696574336,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-TtwgUdM7aW7ehfeqaUcshTtg",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 20406,
//       created_at: 1695271267,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-LbiTFrHKVAfDnqNROQfoyAh8",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 2939,
//       created_at: 1695269741,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-HtPWASZzc0LLlvEY7ENy0q13",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 2182182,
//       created_at: 1695269567,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-tvMCiFdyYm2dUMapVpshLz92",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 274378,
//       created_at: 1695269321,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-kGrPBJvxZyY2UREqrVCfS1SQ",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 20175,
//       created_at: 1695259469,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-0cV48SeSvxS014Ack1Y7FyHq",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 2303986,
//       created_at: 1695257970,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-AnvsaIFnMrpFHqARI3wzR7Om",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 20165,
//       created_at: 1695105409,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-UrGGUOin9fManPfygLuDlELi",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 2302935,
//       created_at: 1695103517,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-3Jr6Z1mqgUeC99NLGKdTK9VU",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 2303069,
//       created_at: 1695103150,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-6yxuJzqQRGv1GfIzE5Y0Fiqj",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 2379718,
//       created_at: 1695103054,
//       status: "error",
//       status_details: "Invalid file format. Example 40, message 4, value None for key content is not a string."
//     },
//     {
//       object: "file",
//       id: "file-M9L3n30ftD1WUJlfnvsv3sBn",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 2379718,
//       created_at: 1695102971,
//       status: "error",
//       status_details: "Invalid file format. Example 40, message 4, value None for key content is not a string."
//     },
//     {
//       object: "file",
//       id: "file-N3hzCW3E95Q7hYt8RE5rXZHH",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 3824,
//       created_at: 1694301482,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-KcwmPPa01K09HPBOHBlVM930",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 977062,
//       created_at: 1694300541,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-hIhhS9EBm9jvr3bdQ76nEV5D",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 977062,
//       created_at: 1694299996,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-HJnpdWq389i3E1grobYHHg3S",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 973704,
//       created_at: 1694299581,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-itOK2JBz9aDFnbboFVxSlb6v",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 968886,
//       created_at: 1694299411,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-3m080N3WMfXPYpoN5VcKHXET",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 1631,
//       created_at: 1693719731,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-jmqHqJVNMDt8YaWS7JaqSOT2",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 141994,
//       created_at: 1693719081,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-s8yH11pgszUBqIeCbuSrIeeW",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 28398,
//       created_at: 1693719037,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-KMDtl0c72dzAPCsi32zt7LuD",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 3821,
//       created_at: 1693347734,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Zu8UwDylxzikViJ6fhNrX4vO",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 963387,
//       created_at: 1693346963,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-ZtXgzqi7bPhvClEEGhdKeHQ9",
//       purpose: "fine-tune",
//       filename: "examples.jsonl",
//       bytes: 963387,
//       created_at: 1693346812,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-2LQrTDMdAf7RCl9bllkh5fq5",
//       purpose: "fine-tune",
//       filename: "examples.jsonl",
//       bytes: 963387,
//       created_at: 1693346585,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-pVXGYydVdQoZ3ekgQQZNHbS4",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 14882,
//       created_at: 1693090386,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-55KQkM7FjY1zSDQBBHrO3Yjo",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 14873,
//       created_at: 1693088781,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-hh1VsEhfogJrVoGD2o1tQWIC",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 445244,
//       created_at: 1693087291,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Hym38LhaBJIlCmy7ffjGRqcQ",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 2537,
//       created_at: 1692840908,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-5kiW4OE4yNIDtSsgieVQO3aC",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 2534,
//       created_at: 1692834768,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-BIY5uqyb0k1S43c6lUTg78vT",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 2536,
//       created_at: 1692833641,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-AkC9qKP37zaAJrXHSMHCPtfo",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 2536,
//       created_at: 1692832195,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-oRm8O48ZPtfo4V1ojfQkb0Hx",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 8566,
//       created_at: 1692831523,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Vp2tXt7iEcolcWS9fDIDbrJA",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 8566,
//       created_at: 1692831446,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-1r2nUlEWXsMM3l6c3ySNJhVp",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 2537,
//       created_at: 1692830105,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-oJnvEfHJBOjxnw0fwVI07AlM",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 8566,
//       created_at: 1692829400,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Q51jcoJ9j1V4wk1rgCKfGZuU",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 6262,
//       created_at: 1692829324,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-7ySzIB1oBRIDcfiZZSn4FHCM",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 105383,
//       created_at: 1692811809,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-0mZu3g9fMaE0rxC5tgAjiVke",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 1475,
//       created_at: 1692810960,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-03vGq2Q9l136VxrvLB8iflQw",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 105383,
//       created_at: 1692810257,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-YHUbgwZAMZXCz6LtX8UcL5Hb",
//       purpose: "fine-tune-results",
//       filename: "step_metrics.csv",
//       bytes: 2638,
//       created_at: 1692740830,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-61DQYPcXDazjyFdk8gIVwv6J",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 59430,
//       created_at: 1692740164,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-AOVf1DUY9IJZ6DiTlf8OI0du",
//       purpose: "fine-tune",
//       filename: "file",
//       bytes: 59430,
//       created_at: 1692740116,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-YvuO6n7fHa4Ab4f7WLA0LrMY",
//       purpose: "fine-tune-results",
//       filename: "compiled_results.csv",
//       bytes: 38918,
//       created_at: 1683768553,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-ywdSfaiNwSKZPF6sKvJrZhFQ",
//       purpose: "fine-tune",
//       filename: "finetune.jsonl",
//       bytes: 1219476,
//       created_at: 1683767421,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-uSuzKUnX02Vi6Zx4wkAUQTOX",
//       purpose: "fine-tune-results",
//       filename: "compiled_results.csv",
//       bytes: 199355,
//       created_at: 1664822707,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-YquSBCmUrM9lgZqClLcNVXWA",
//       purpose: "fine-tune",
//       filename: "docs_blurbs_prepared.jsonl",
//       bytes: 2773423,
//       created_at: 1664820476,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-Iz6A07iIWaUWOGfH6Tur4YfR",
//       purpose: "fine-tune-results",
//       filename: "compiled_results.csv",
//       bytes: 693,
//       created_at: 1663314732,
//       status: "processed",
//       status_details: null
//     },
//     {
//       object: "file",
//       id: "file-KHQAVwAogvWFjzI8jJ2ZQDJE",
//       purpose: "fine-tune",
//       filename: "training_prepared.jsonl",
//       bytes: 1889,
//       created_at: 1663309724,
//       status: "processed",
//       status_details: null
//     }
//   ],
//   object: "list"
// }

// %% [markdown]
// ## Retrieve File
//
// Returns information about a specific file.

// %%
import { OpenAIFiles } from "langchain/experimental/openai_files";

const openAIFiles = new OpenAIFiles();
await openAIFiles.retrieveFile({ fileId: file.id });
// Out:
// {
//   object: "file",
//   id: "file-dBLRDhxODeEUeJKEpOtZqT5Q",
//   purpose: "assistants",
//   filename: "state_of_the_union.txt",
//   bytes: 39027,
//   created_at: 1703627254,
//   status: "processed",
//   status_details: null
// }
