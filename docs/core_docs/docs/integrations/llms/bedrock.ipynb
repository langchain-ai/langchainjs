// %% [raw]
// ---
// sidebar_label: Bedrock
// ---

// %% [markdown]
// # Bedrock
//
// ```{=mdx}
//
// :::caution
// You are currently on a page documenting the use of Amazon Bedrock models as [text completion models](/docs/concepts/#llms). Many popular models available on Bedrock are [chat completion models](/docs/concepts/#chat-models).
//
// You may be looking for [this page instead](/docs/integrations/chat/bedrock/).
// :::
//
// ```
//
// > [Amazon Bedrock](https://aws.amazon.com/bedrock/) is a fully managed service that makes Foundation Models (FMs)
// > from leading AI startups and Amazon available via an API. You can choose from a wide range of FMs to find the model that is best suited for your use case.
//
// This will help you get started with Bedrock completion models (LLMs) using LangChain. For detailed documentation on `Bedrock` features and configuration options, please refer to the [API reference](https://api.js.langchain.com/classes/langchain_community_llms_bedrock.Bedrock.html).
//
// ## Overview
// ### Integration details
//
// - TODO: Fill in table features.
// - TODO: Remove JS support link if not relevant, otherwise ensure link is correct.
// - TODO: Make sure API reference links are correct.
//
// | Class | Package | Local | Serializable | [PY support](https://python.langchain.com/docs/integrations/llms/bedrock) | Package downloads | Package latest |
// | :--- | :--- | :---: | :---: |  :---: | :---: | :---: |
// | [Bedrock](https://api.js.langchain.com/classes/langchain_community_llms_bedrock.Bedrock.html) | [@langchain/community](https://api.js.langchain.com/modules/langchain_community_llms_bedrock.html) | ❌ | ✅ | ✅ | ![NPM - Downloads](https://img.shields.io/npm/dm/@langchain/community?style=flat-square&label=%20&) | ![NPM - Version](https://img.shields.io/npm/v/@langchain/community?style=flat-square&label=%20&) |
//
// ## Setup
//
// To access Bedrock models you'll need to create an AWS account, get an API key, and install the `@langchain/community` integration, along with a few peer dependencies.
//
// ### Credentials
//
// Head to [aws.amazon.com](https://aws.amazon.com) to sign up to AWS Bedrock and generate an API key. Once you've done this set the environment variables:
//
// ```bash
// export BEDROCK_AWS_REGION="your-region-url"
// export BEDROCK_AWS_ACCESS_KEY_ID="your-access-key-id"
// export BEDROCK_AWS_SECRET_ACCESS_KEY="your-secret-access-key"
// ```
//
// If you want to get automated tracing of your model calls you can also set your [LangSmith](https://docs.smith.langchain.com/) API key by uncommenting below:
//
// ```bash
// # export LANGCHAIN_TRACING_V2="true"
// # export LANGCHAIN_API_KEY="your-api-key"
// ```
//
// ### Installation
//
// The LangChain Bedrock integration lives in the `@langchain/community` package:
//
// ```{=mdx}
// import IntegrationInstallTooltip from "@mdx_components/integration_install_tooltip.mdx";
// import Npm2Yarn from "@theme/Npm2Yarn";
//
// <IntegrationInstallTooltip></IntegrationInstallTooltip>
//
// <Npm2Yarn>
//   @langchain/community
// </Npm2Yarn>
//
// And install the peer dependencies:
//
// <Npm2Yarn>
//   @aws-crypto/sha256-js @aws-sdk/credential-provider-node @smithy/protocol-http @smithy/signature-v4 @smithy/eventstream-codec @smithy/util-utf8 @aws-sdk/types
// </Npm2Yarn>
//
// You can also use Bedrock in web environments such as Edge functions or Cloudflare Workers by omitting the `@aws-sdk/credential-provider-node` dependency
// and using the `web` entrypoint:
//
// <Npm2Yarn>
//   @aws-crypto/sha256-js @smithy/protocol-http @smithy/signature-v4 @smithy/eventstream-codec @smithy/util-utf8 @aws-sdk/types
// </Npm2Yarn>
//
// ```

// %% [markdown]
// ## Instantiation
//
// Now we can instantiate our model object and generate chat completions:

// %%
// @lc-docs-hide-cell
// Deno requires these imports, and way of loading env vars.
// we don't want to expose in the docs.
// Below this cell we have a typescript markdown codeblock with
// the node code.
import "@aws-sdk/credential-provider-node";
import "@smithy/protocol-http";
import "@aws-crypto/sha256-js";
import "@smithy/protocol-http";
import "@smithy/signature-v4";
import "@smithy/eventstream-codec";
import "@smithy/util-utf8";
import "@aws-sdk/types";
import { Bedrock } from "@langchain/community/llms/bedrock"

const llm = new Bedrock({
  model: "anthropic.claude-v2",
  region: "us-east-1",
  // endpointUrl: "custom.amazonaws.com",
  credentials: {
    accessKeyId: Deno.env.get("BEDROCK_AWS_ACCESS_KEY_ID"),
    secretAccessKey: Deno.env.get("BEDROCK_AWS_SECRET_ACCESS_KEY"),
  },
  temperature: 0,
  maxTokens: undefined,
  maxRetries: 2,
  // other params...
})
// Out:
// [Module: null prototype] {
//   EndpointURLScheme: { HTTP: "http", HTTPS: "https" },
//   HostAddressType: { AAAA: "AAAA", A: "A" },
//   HttpAuthLocation: { HEADER: "header", QUERY: "query" },
//   RequestHandlerProtocol: { HTTP_0_9: "http/0.9", HTTP_1_0: "http/1.0", TDS_8_0: "tds/8.0" },
//   default: {
//     AbortController: [Getter],
//     AbortHandler: [Getter],
//     AbortSignal: [Getter],
//     AbsoluteLocation: [Getter],
//     AuthScheme: [Getter],
//     AvailableMessage: [Getter],
//     AvailableMessages: [Getter],
//     AwsCredentialIdentity: [Getter],
//     AwsCredentialIdentityProvider: [Getter],
//     BinaryHeaderValue: [Getter],
//     BlobTypes: [Getter],
//     BodyLengthCalculator: [Getter],
//     BooleanHeaderValue: [Getter],
//     BuildHandler: [Getter],
//     BuildHandlerArguments: [Getter],
//     BuildHandlerOptions: [Getter],
//     BuildHandlerOutput: [Getter],
//     BuildMiddleware: [Getter],
//     ByteHeaderValue: [Getter],
//     Checksum: [Getter],
//     ChecksumConstructor: [Getter],
//     Client: [Getter],
//     Command: [Getter],
//     ConnectConfiguration: [Getter],
//     ConnectionManager: [Getter],
//     ConnectionManagerConfiguration: [Getter],
//     ConnectionPool: [Getter],
//     DateInput: [Getter],
//     Decoder: [Getter],
//     DeserializeHandler: [Getter],
//     DeserializeHandlerArguments: [Getter],
//     DeserializeHandlerOptions: [Getter],
//     DeserializeHandlerOutput: [Getter],
//     DeserializeMiddleware: [Getter],
//     DocumentType: [Getter],
//     Encoder: [Getter],
//     Endpoint: [Getter],
//     EndpointARN: [Getter],
//     EndpointBearer: [Getter],
//     EndpointObjectProperty: [Getter],
//     EndpointParameters: [Getter],
//     EndpointPartition: [Getter],
//     EndpointURL: [Getter],
//     EndpointURLScheme: [Getter],
//     EndpointV2: [Getter],
//     EventSigner: [Getter],
//     EventSigningArguments: [Getter],
//     EventStreamMarshaller: [Getter],
//     EventStreamMarshallerDeserFn: [Getter],
//     EventStreamMarshallerSerFn: [Getter],
//     EventStreamPayloadHandler: [Getter],
//     EventStreamPayloadHandlerProvider: [Getter],
//     EventStreamRequestSigner: [Getter],
//     EventStreamSerdeContext: [Getter],
//     EventStreamSerdeProvider: [Getter],
//     EventStreamSignerProvider: [Getter],
//     ExponentialBackoffJitterType: [Getter],
//     ExponentialBackoffStrategyOptions: [Getter],
//     FinalizeHandler: [Getter],
//     FinalizeHandlerArguments: [Getter],
//     FinalizeHandlerOutput: [Getter],
//     FinalizeRequestHandlerOptions: [Getter],
//     FinalizeRequestMiddleware: [Getter],
//     FormattedEvent: [Getter],
//     GetAwsChunkedEncodingStream: [Getter],
//     GetAwsChunkedEncodingStreamOptions: [Getter],
//     Handler: [Getter],
//     HandlerExecutionContext: [Getter],
//     HandlerOptions: [Getter],
//     Hash: [Getter],
//     HashConstructor: [Getter],
//     HeaderBag: [Getter],
//     HostAddressType: [Getter],
//     HttpAuthDefinition: [Getter],
//     HttpAuthLocation: [Getter],
//     HttpHandlerOptions: [Getter],
//     HttpMessage: [Getter],
//     HttpRequest: [Getter],
//     HttpResponse: [Getter],
//     Identity: [Getter],
//     IdentityProvider: [Getter],
//     IniSection: [Getter],
//     InitializeHandler: [Getter],
//     InitializeHandlerArguments: [Getter],
//     InitializeHandlerOptions: [Getter],
//     InitializeHandlerOutput: [Getter],
//     InitializeMiddleware: [Getter],
//     Int64: [Getter],
//     IntegerHeaderValue: [Getter],
//     LongHeaderValue: [Getter],
//     MemoizedProvider: [Getter],
//     Message: [Getter],
//     MessageDecoder: [Getter],
//     MessageEncoder: [Getter],
//     MessageHeaderValue: [Getter],
//     MessageHeaders: [Getter],
//     MessageSigner: [Getter],
//     MetadataBearer: [Getter],
//     MiddlewareStack: [Getter],
//     MiddlewareType: [Getter],
//     PaginationConfiguration: [Getter],
//     Paginator: [Getter],
//     ParsedIniData: [Getter],
//     Pluggable: [Getter],
//     Priority: [Getter],
//     Profile: [Getter],
//     Provider: [Getter],
//     QueryParameterBag: [Getter],
//     RegionInfo: [Getter],
//     RegionInfoProvider: [Getter],
//     RegionInfoProviderOptions: [Getter],
//     Relation: [Getter],
//     RelativeLocation: [Getter],
//     RelativeMiddlewareOptions: [Getter],
//     RequestContext: [Getter],
//     RequestHandler: [Getter],
//     RequestHandlerMetadata: [Getter],
//     RequestHandlerOutput: [Getter],
//     RequestHandlerProtocol: [Getter],
//     RequestPresigner: [Getter],
//     RequestPresigningArguments: [Getter],
//     RequestSerializer: [Getter],
//     RequestSigner: [Getter],
//     RequestSigningArguments: [Getter],
//     ResponseDeserializer: [Getter],
//     ResponseMetadata: [Getter],
//     RetryBackoffStrategy: [Getter],
//     RetryErrorInfo: [Getter],
//     RetryErrorType: [Getter],
//     RetryStrategy: [Getter],
//     RetryStrategyOptions: [Getter],
//     RetryStrategyV2: [Getter],
//     RetryToken: [Getter],
//     RetryableTrait: [Getter],
//     SdkError: [Getter],
//     SdkStream: [Getter],
//     SdkStreamMixin: [Getter],
//     SdkStreamMixinInjector: [Getter],
//     SdkStreamSerdeContext: [Getter],
//     SerdeContext: [Getter],
//     SerializeHandler: [Getter],
//     SerializeHandlerArguments: [Getter],
//     SerializeHandlerOptions: [Getter],
//     SerializeHandlerOutput: [Getter],
//     SerializeMiddleware: [Getter],
//     SharedConfigFiles: [Getter],
//     ShortHeaderValue: [Getter],
//     SignableMessage: [Getter],
//     SignedMessage: [Getter],
//     SigningArguments: [Getter],
//     SmithyException: [Getter],
//     SourceData: [Getter],
//     StandardRetryBackoffStrategy: [Getter],
//     StandardRetryToken: [Getter],
//     Step: [Getter],
//     StreamCollector: [Getter],
//     StreamHasher: [Getter],
//     StringHeaderValue: [Getter],
//     StringSigner: [Getter],
//     Terminalware: [Getter],
//     TimestampHeaderValue: [Getter],
//     TokenIdentity: [Getter],
//     TokenIdentityProvider: [Getter],
//     URI: [Getter],
//     UrlParser: [Getter],
//     UserAgent: [Getter],
//     UserAgentPair: [Getter],
//     UuidHeaderValue: [Getter],
//     WaiterConfiguration: [Getter],
//     WithSdkStreamMixin: [Getter],
//     randomValues: [Getter]
//   }
// }

// %% [markdown]
// ```typescript
// import { Bedrock } from "@langchain/community/llms/bedrock"
//
// const llm = new Bedrock({
//   model: "anthropic.claude-v2",
//   region: process.env.BEDROCK_AWS_REGION ?? "us-east-1",
//   // endpointUrl: "custom.amazonaws.com",
//   credentials: {
//     accessKeyId: process.env.BEDROCK_AWS_ACCESS_KEY_ID,
//     secretAccessKey: process.env.BEDROCK_AWS_SECRET_ACCESS_KEY,
//   },
//   temperature: 0,
//   maxTokens: undefined,
//   maxRetries: 2,
//   // other params...
// })
// ```

// %% [markdown]
// ## Invocation
//
// Note that some models require specific prompting techniques. For example, Anthropic's Claude-v2 model will throw an error if
// the prompt does not start with `Human: `.

// %%
const inputText = "Human: Bedrock is an AI company that\nAssistant: "

const completion = await llm.invoke(inputText)
completion
// Out:
// " Here are a few key points about Bedrock AI:\n" +
//   "\n" +
//   "- Bedrock was founded in 2021 and is based in San Fran"... 113 more characters

// %% [markdown]
// ## Chaining
//
// We can [chain](/docs/how_to/sequence/) our completion model with a prompt template like so:

// %%
import { PromptTemplate } from "@langchain/core/prompts"

const prompt = new PromptTemplate({
  template: "Human: How to say {input} in {output_language}:\nAssistant:",
  inputVariables: ["input", "output_language"],
})

const chain = prompt.pipe(llm);
await chain.invoke(
  {
    output_language: "German",
    input: "I love programming.",
  }
)
// Out:
// ' Here is how to say "I love programming" in German:\n' +
//   "\n" +
//   "Ich liebe das Programmieren."

// %% [markdown]
// ## API reference
//
// For detailed documentation of all Bedrock features and configurations head to the API reference: https://api.js.langchain.com/classes/langchain_community_llms_bedrock.Bedrock.html
